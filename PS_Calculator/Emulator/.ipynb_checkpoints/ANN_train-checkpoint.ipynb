# %%
import torch.nn as nn
import torch
from torch.utils.data import TensorDataset, DataLoader
import numpy as np

# %%
from neuralnet_arch import Net
# -----------------------------
# Global Parameters
# -----------------------------
NUM_INPUTS = 4
NUM_OUTPUTS = 4
BATCH_SIZE = 64
NUM_EPOCHS = 1000
LEARNING_RATE = 1e-3
VAL_SPLIT = 0.2
RANDOM_SEED = 42
DATA_PATH = "gen_data.txt"  # <-- change this to your data file path

# -----------------------------
# Load and Split Data
# -----------------------------
def load_and_split_data(file_path, val_split=0.2, random_seed=42):
    data = np.loadtxt(file_path, delimiter=",")
    np.random.seed(random_seed)
    indices = np.random.permutation(len(data))
    data = data[indices]

    X = data[:, :NUM_INPUTS]
    y = data[:, NUM_INPUTS:NUM_INPUTS + NUM_OUTPUTS]

    #Log transform x data
    X = np.log10(X)

    n_total = len(X)
    n_val = int(n_total * val_split)
    n_train = n_total - n_val

    X_train, y_train = X[:n_train], y[:n_train]
    X_val, y_val = X[n_train:], y[n_train:]

    return X_train, X_val, y_train, y_val

# -----------------------------
# Training Function
# -----------------------------
def train_model(model, train_loader, val_loader, num_epochs, lr, device,checkpoint_path,patience=20):
    model.to(device)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    best_val_loss = float('inf')  # Initialize with a large value
    epochs_no_improve = 0

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * X_batch.size(0)
        train_loss /= len(train_loader.dataset)

        # Validation
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                X_batch, y_batch = X_batch.to(device), y_batch.to(device)
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)
                val_loss += loss.item() * X_batch.size(0)
        val_loss /= len(val_loader.dataset)

        print(f"Epoch [{epoch+1}/{num_epochs}] - Train Loss: {train_loss:.4f} - Val Loss: {val_loss:.4f}")
        
        # Save the model checkpoint if validation loss improved
        if val_loss < best_val_loss:
            print(f"Validation loss decreased ({best_val_loss:.4f} -> {val_loss:.4f}). Saving model...")
            best_val_loss = val_loss
            torch.save(model.state_dict(), checkpoint_path)
            epochs_no_improve = 0  # Reset counter
        else:
            epochs_no_improve += 1
            print(f"No improvement for {epochs_no_improve} epoch(s).")

        # Early stopping
        if epochs_no_improve >= patience:
            print(f"Early stopping triggered after {epoch+1} epochs. Best val loss: {best_val_loss:.4f}")
            break


# -----------------------------
# Main Execution
# -----------------------------
def main():
    # Load and prepare data
    X_train, X_val, y_train, y_val = load_and_split_data(DATA_PATH, val_split=VAL_SPLIT, random_seed=RANDOM_SEED)

    # Convert to PyTorch tensors
    X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
    y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
    X_val_tensor   = torch.tensor(X_val, dtype=torch.float32)
    y_val_tensor   = torch.tensor(y_val, dtype=torch.float32)

    # Create datasets and loaders
    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    val_dataset   = TensorDataset(X_val_tensor, y_val_tensor)

    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
    val_loader   = DataLoader(val_dataset, batch_size=BATCH_SIZE)

    # Model
    model = Net(input_dim=NUM_INPUTS, output_dim=NUM_OUTPUTS)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Train
    train_model(model, train_loader, val_loader, num_epochs=NUM_EPOCHS, lr=LEARNING_RATE, device=device,checkpoint_path="test.pth")
main()
# Out:
# Epoch [1/1000] - Train Loss: 28.7768 - Val Loss: 1.6491
# Validation loss decreased (inf -> 1.6491). Saving model...
# Epoch [2/1000] - Train Loss: 1.3565 - Val Loss: 1.2645
# Validation loss decreased (1.6491 -> 1.2645). Saving model...
# Epoch [3/1000] - Train Loss: 1.0547 - Val Loss: 0.9881
# Validation loss decreased (1.2645 -> 0.9881). Saving model...
# Epoch [4/1000] - Train Loss: 0.8340 - Val Loss: 0.8493
# Validation loss decreased (0.9881 -> 0.8493). Saving model...
# Epoch [5/1000] - Train Loss: 0.6950 - Val Loss: 0.6907
# Validation loss decreased (0.8493 -> 0.6907). Saving model...
# Epoch [6/1000] - Train Loss: 0.6261 - Val Loss: 0.6272
# Validation loss decreased (0.6907 -> 0.6272). Saving model...
# Epoch [7/1000] - Train Loss: 0.5856 - Val Loss: 0.5797
# Validation loss decreased (0.6272 -> 0.5797). Saving model...
# Epoch [8/1000] - Train Loss: 0.5649 - Val Loss: 0.5404
# Validation loss decreased (0.5797 -> 0.5404). Saving model...
# Epoch [9/1000] - Train Loss: 0.5156 - Val Loss: 0.4955
# Validation loss decreased (0.5404 -> 0.4955). Saving model...
# Epoch [10/1000] - Train Loss: 0.4713 - Val Loss: 0.4365
# Validation loss decreased (0.4955 -> 0.4365). Saving model...
# Epoch [11/1000] - Train Loss: 0.4226 - Val Loss: 0.4027
# Validation loss decreased (0.4365 -> 0.4027). Saving model...
# Epoch [12/1000] - Train Loss: 0.3568 - Val Loss: 0.3190
# Validation loss decreased (0.4027 -> 0.3190). Saving model...
# Epoch [13/1000] - Train Loss: 0.2962 - Val Loss: 0.2606
# Validation loss decreased (0.3190 -> 0.2606). Saving model...
# Epoch [14/1000] - Train Loss: 0.2477 - Val Loss: 0.2137
# Validation loss decreased (0.2606 -> 0.2137). Saving model...
# Epoch [15/1000] - Train Loss: 0.2118 - Val Loss: 0.1887
# Validation loss decreased (0.2137 -> 0.1887). Saving model...
# Epoch [16/1000] - Train Loss: 0.2079 - Val Loss: 0.1615
# Validation loss decreased (0.1887 -> 0.1615). Saving model...
# Epoch [17/1000] - Train Loss: 0.1736 - Val Loss: 0.1493
# Validation loss decreased (0.1615 -> 0.1493). Saving model...
# Epoch [18/1000] - Train Loss: 0.1561 - Val Loss: 0.1377
# Validation loss decreased (0.1493 -> 0.1377). Saving model...
# Epoch [19/1000] - Train Loss: 0.1489 - Val Loss: 0.1325
# Validation loss decreased (0.1377 -> 0.1325). Saving model...
# Epoch [20/1000] - Train Loss: 0.1371 - Val Loss: 0.1857
# No improvement for 1 epoch(s).
# Epoch [21/1000] - Train Loss: 0.1415 - Val Loss: 0.1239
# Validation loss decreased (0.1325 -> 0.1239). Saving model...
# Epoch [22/1000] - Train Loss: 0.1312 - Val Loss: 0.1196
# Validation loss decreased (0.1239 -> 0.1196). Saving model...
# Epoch [23/1000] - Train Loss: 0.1343 - Val Loss: 0.1143
# Validation loss decreased (0.1196 -> 0.1143). Saving model...
# Epoch [24/1000] - Train Loss: 0.1199 - Val Loss: 0.1152
# No improvement for 1 epoch(s).
# Epoch [25/1000] - Train Loss: 0.1183 - Val Loss: 0.1216
# No improvement for 2 epoch(s).
# Epoch [26/1000] - Train Loss: 0.1115 - Val Loss: 0.1027
# Validation loss decreased (0.1143 -> 0.1027). Saving model...
# Epoch [27/1000] - Train Loss: 0.1073 - Val Loss: 0.1017
# Validation loss decreased (0.1027 -> 0.1017). Saving model...
# Epoch [28/1000] - Train Loss: 0.1079 - Val Loss: 0.0965
# Validation loss decreased (0.1017 -> 0.0965). Saving model...
# Epoch [29/1000] - Train Loss: 0.1003 - Val Loss: 0.1439
# No improvement for 1 epoch(s).
# Epoch [30/1000] - Train Loss: 0.1089 - Val Loss: 0.1022
# No improvement for 2 epoch(s).
# Epoch [31/1000] - Train Loss: 0.0978 - Val Loss: 0.1538
# No improvement for 3 epoch(s).
# Epoch [32/1000] - Train Loss: 0.0926 - Val Loss: 0.1199
# No improvement for 4 epoch(s).
# Epoch [33/1000] - Train Loss: 0.0868 - Val Loss: 0.0812
# Validation loss decreased (0.0965 -> 0.0812). Saving model...
# Epoch [34/1000] - Train Loss: 0.0791 - Val Loss: 0.0755
# Validation loss decreased (0.0812 -> 0.0755). Saving model...
# Epoch [35/1000] - Train Loss: 0.0796 - Val Loss: 0.0899
# No improvement for 1 epoch(s).
# Epoch [36/1000] - Train Loss: 0.0788 - Val Loss: 0.0705
# Validation loss decreased (0.0755 -> 0.0705). Saving model...
# Epoch [37/1000] - Train Loss: 0.0738 - Val Loss: 0.0632
# Validation loss decreased (0.0705 -> 0.0632). Saving model...
# Epoch [38/1000] - Train Loss: 0.0669 - Val Loss: 0.0597
# Validation loss decreased (0.0632 -> 0.0597). Saving model...
# Epoch [39/1000] - Train Loss: 0.0647 - Val Loss: 0.0601
# No improvement for 1 epoch(s).
# Epoch [40/1000] - Train Loss: 0.0640 - Val Loss: 0.0559
# Validation loss decreased (0.0597 -> 0.0559). Saving model...
# Epoch [41/1000] - Train Loss: 0.0616 - Val Loss: 0.0544
# Validation loss decreased (0.0559 -> 0.0544). Saving model...
# Epoch [42/1000] - Train Loss: 0.0556 - Val Loss: 0.0485
# Validation loss decreased (0.0544 -> 0.0485). Saving model...
# Epoch [43/1000] - Train Loss: 0.0560 - Val Loss: 0.0494
# No improvement for 1 epoch(s).
# Epoch [44/1000] - Train Loss: 0.0547 - Val Loss: 0.0589
# No improvement for 2 epoch(s).
# Epoch [45/1000] - Train Loss: 0.0464 - Val Loss: 0.0471
# Validation loss decreased (0.0485 -> 0.0471). Saving model...
# Epoch [46/1000] - Train Loss: 0.0442 - Val Loss: 0.0389
# Validation loss decreased (0.0471 -> 0.0389). Saving model...
# Epoch [47/1000] - Train Loss: 0.0466 - Val Loss: 0.0451
# No improvement for 1 epoch(s).
# Epoch [48/1000] - Train Loss: 0.0408 - Val Loss: 0.0380
# Validation loss decreased (0.0389 -> 0.0380). Saving model...
# Epoch [49/1000] - Train Loss: 0.0419 - Val Loss: 0.0387
# No improvement for 1 epoch(s).
# Epoch [50/1000] - Train Loss: 0.0379 - Val Loss: 0.0419
# No improvement for 2 epoch(s).
# Epoch [51/1000] - Train Loss: 0.0345 - Val Loss: 0.0338
# Validation loss decreased (0.0380 -> 0.0338). Saving model...
# Epoch [52/1000] - Train Loss: 0.0317 - Val Loss: 0.0272
# Validation loss decreased (0.0338 -> 0.0272). Saving model...
# Epoch [53/1000] - Train Loss: 0.0299 - Val Loss: 0.0344
# No improvement for 1 epoch(s).
# Epoch [54/1000] - Train Loss: 0.0271 - Val Loss: 0.0231
# Validation loss decreased (0.0272 -> 0.0231). Saving model...
# Epoch [55/1000] - Train Loss: 0.0298 - Val Loss: 0.0233
# No improvement for 1 epoch(s).
# Epoch [56/1000] - Train Loss: 0.0276 - Val Loss: 0.0218
# Validation loss decreased (0.0231 -> 0.0218). Saving model...
# Epoch [57/1000] - Train Loss: 0.0243 - Val Loss: 0.0199
# Validation loss decreased (0.0218 -> 0.0199). Saving model...
# Epoch [58/1000] - Train Loss: 0.0238 - Val Loss: 0.0440
# No improvement for 1 epoch(s).
# Epoch [59/1000] - Train Loss: 0.0243 - Val Loss: 0.0174
# Validation loss decreased (0.0199 -> 0.0174). Saving model...
# Epoch [60/1000] - Train Loss: 0.0193 - Val Loss: 0.0205
# No improvement for 1 epoch(s).
# Epoch [61/1000] - Train Loss: 0.0175 - Val Loss: 0.0295
# No improvement for 2 epoch(s).
# Epoch [62/1000] - Train Loss: 0.0207 - Val Loss: 0.0146
# Validation loss decreased (0.0174 -> 0.0146). Saving model...
# Epoch [63/1000] - Train Loss: 0.0172 - Val Loss: 0.0179
# No improvement for 1 epoch(s).
# Epoch [64/1000] - Train Loss: 0.0132 - Val Loss: 0.0113
# Validation loss decreased (0.0146 -> 0.0113). Saving model...
# Epoch [65/1000] - Train Loss: 0.0124 - Val Loss: 0.0124
# No improvement for 1 epoch(s).
# Epoch [66/1000] - Train Loss: 0.0120 - Val Loss: 0.0122
# No improvement for 2 epoch(s).
# Epoch [67/1000] - Train Loss: 0.0098 - Val Loss: 0.0089
# Validation loss decreased (0.0113 -> 0.0089). Saving model...
# Epoch [68/1000] - Train Loss: 0.0098 - Val Loss: 0.0120
# No improvement for 1 epoch(s).
# Epoch [69/1000] - Train Loss: 0.0137 - Val Loss: 0.0178
# No improvement for 2 epoch(s).
# Epoch [70/1000] - Train Loss: 0.0103 - Val Loss: 0.0103
# No improvement for 3 epoch(s).
# Epoch [71/1000] - Train Loss: 0.0081 - Val Loss: 0.0114
# No improvement for 4 epoch(s).
# Epoch [72/1000] - Train Loss: 0.0075 - Val Loss: 0.0081
# Validation loss decreased (0.0089 -> 0.0081). Saving model...
# Epoch [73/1000] - Train Loss: 0.0075 - Val Loss: 0.0077
# Validation loss decreased (0.0081 -> 0.0077). Saving model...
# Epoch [74/1000] - Train Loss: 0.0068 - Val Loss: 0.0078
# No improvement for 1 epoch(s).
# Epoch [75/1000] - Train Loss: 0.0069 - Val Loss: 0.0145
# No improvement for 2 epoch(s).
# Epoch [76/1000] - Train Loss: 0.0073 - Val Loss: 0.0064
# Validation loss decreased (0.0077 -> 0.0064). Saving model...
# Epoch [77/1000] - Train Loss: 0.0063 - Val Loss: 0.0053
# Validation loss decreased (0.0064 -> 0.0053). Saving model...
# Epoch [78/1000] - Train Loss: 0.0055 - Val Loss: 0.0051
# Validation loss decreased (0.0053 -> 0.0051). Saving model...
# Epoch [79/1000] - Train Loss: 0.0065 - Val Loss: 0.0043
# Validation loss decreased (0.0051 -> 0.0043). Saving model...
# Epoch [80/1000] - Train Loss: 0.0061 - Val Loss: 0.0194
# No improvement for 1 epoch(s).
# Epoch [81/1000] - Train Loss: 0.0064 - Val Loss: 0.0158
# No improvement for 2 epoch(s).
# Epoch [82/1000] - Train Loss: 0.0081 - Val Loss: 0.0069
# No improvement for 3 epoch(s).
# Epoch [83/1000] - Train Loss: 0.0064 - Val Loss: 0.0057
# No improvement for 4 epoch(s).
# Epoch [84/1000] - Train Loss: 0.0061 - Val Loss: 0.0088
# No improvement for 5 epoch(s).
# Epoch [85/1000] - Train Loss: 0.0063 - Val Loss: 0.0050
# No improvement for 6 epoch(s).
# Epoch [86/1000] - Train Loss: 0.0071 - Val Loss: 0.0052
# No improvement for 7 epoch(s).
# Epoch [87/1000] - Train Loss: 0.0054 - Val Loss: 0.0042
# Validation loss decreased (0.0043 -> 0.0042). Saving model...
# Epoch [88/1000] - Train Loss: 0.0052 - Val Loss: 0.0052
# No improvement for 1 epoch(s).
# Epoch [89/1000] - Train Loss: 0.0051 - Val Loss: 0.0051
# No improvement for 2 epoch(s).
# Epoch [90/1000] - Train Loss: 0.0068 - Val Loss: 0.0067
# No improvement for 3 epoch(s).
# Epoch [91/1000] - Train Loss: 0.0072 - Val Loss: 0.0075
# No improvement for 4 epoch(s).
# Epoch [92/1000] - Train Loss: 0.0065 - Val Loss: 0.0072
# No improvement for 5 epoch(s).
# Epoch [93/1000] - Train Loss: 0.0052 - Val Loss: 0.0062
# No improvement for 6 epoch(s).
# Epoch [94/1000] - Train Loss: 0.0055 - Val Loss: 0.0063
# No improvement for 7 epoch(s).
# Epoch [95/1000] - Train Loss: 0.0061 - Val Loss: 0.0071
# No improvement for 8 epoch(s).
# Epoch [96/1000] - Train Loss: 0.0060 - Val Loss: 0.0038
# Validation loss decreased (0.0042 -> 0.0038). Saving model...
# Epoch [97/1000] - Train Loss: 0.0054 - Val Loss: 0.0094
# No improvement for 1 epoch(s).
# Epoch [98/1000] - Train Loss: 0.0048 - Val Loss: 0.0036
# Validation loss decreased (0.0038 -> 0.0036). Saving model...
# Epoch [99/1000] - Train Loss: 0.0082 - Val Loss: 0.0055
# No improvement for 1 epoch(s).
# Epoch [100/1000] - Train Loss: 0.0143 - Val Loss: 0.0175
# No improvement for 2 epoch(s).
# Epoch [101/1000] - Train Loss: 0.0131 - Val Loss: 0.0071
# No improvement for 3 epoch(s).
# Epoch [102/1000] - Train Loss: 0.0064 - Val Loss: 0.0045
# No improvement for 4 epoch(s).
# Epoch [103/1000] - Train Loss: 0.0054 - Val Loss: 0.0054
# No improvement for 5 epoch(s).
# Epoch [104/1000] - Train Loss: 0.0051 - Val Loss: 0.0038
# No improvement for 6 epoch(s).
# Epoch [105/1000] - Train Loss: 0.0048 - Val Loss: 0.0043
# No improvement for 7 epoch(s).
# Epoch [106/1000] - Train Loss: 0.0046 - Val Loss: 0.0062
# No improvement for 8 epoch(s).
# Epoch [107/1000] - Train Loss: 0.0067 - Val Loss: 0.0066
# No improvement for 9 epoch(s).
# Epoch [108/1000] - Train Loss: 0.0067 - Val Loss: 0.0037
# No improvement for 10 epoch(s).
# Epoch [109/1000] - Train Loss: 0.0061 - Val Loss: 0.0106
# No improvement for 11 epoch(s).
# Epoch [110/1000] - Train Loss: 0.0054 - Val Loss: 0.0042
# No improvement for 12 epoch(s).
# Epoch [111/1000] - Train Loss: 0.0067 - Val Loss: 0.0086
# No improvement for 13 epoch(s).
# Epoch [112/1000] - Train Loss: 0.0057 - Val Loss: 0.0035
# Validation loss decreased (0.0036 -> 0.0035). Saving model...
# Epoch [113/1000] - Train Loss: 0.0054 - Val Loss: 0.0073
# No improvement for 1 epoch(s).
# Epoch [114/1000] - Train Loss: 0.0060 - Val Loss: 0.0047
# No improvement for 2 epoch(s).
# Epoch [115/1000] - Train Loss: 0.0055 - Val Loss: 0.0039
# No improvement for 3 epoch(s).
# Epoch [116/1000] - Train Loss: 0.0054 - Val Loss: 0.0055
# No improvement for 4 epoch(s).
# Epoch [117/1000] - Train Loss: 0.0050 - Val Loss: 0.0036
# No improvement for 5 epoch(s).
# Epoch [118/1000] - Train Loss: 0.0053 - Val Loss: 0.0057
# No improvement for 6 epoch(s).
# Epoch [119/1000] - Train Loss: 0.0085 - Val Loss: 0.0148
# No improvement for 7 epoch(s).
# Epoch [120/1000] - Train Loss: 0.0062 - Val Loss: 0.0112
# No improvement for 8 epoch(s).
# Epoch [121/1000] - Train Loss: 0.0134 - Val Loss: 0.0042
# No improvement for 9 epoch(s).
# Epoch [122/1000] - Train Loss: 0.0054 - Val Loss: 0.0079
# No improvement for 10 epoch(s).
# Epoch [123/1000] - Train Loss: 0.0052 - Val Loss: 0.0038
# No improvement for 11 epoch(s).
# Epoch [124/1000] - Train Loss: 0.0049 - Val Loss: 0.0051
# No improvement for 12 epoch(s).
# Epoch [125/1000] - Train Loss: 0.0051 - Val Loss: 0.0053
# No improvement for 13 epoch(s).
# Epoch [126/1000] - Train Loss: 0.0076 - Val Loss: 0.0294
# No improvement for 14 epoch(s).
# Epoch [127/1000] - Train Loss: 0.0076 - Val Loss: 0.0066
# No improvement for 15 epoch(s).
# Epoch [128/1000] - Train Loss: 0.0064 - Val Loss: 0.0037
# No improvement for 16 epoch(s).
# Epoch [129/1000] - Train Loss: 0.0051 - Val Loss: 0.0054
# No improvement for 17 epoch(s).
# Epoch [130/1000] - Train Loss: 0.0065 - Val Loss: 0.0074
# No improvement for 18 epoch(s).
# Epoch [131/1000] - Train Loss: 0.0057 - Val Loss: 0.0059
# No improvement for 19 epoch(s).
# Epoch [132/1000] - Train Loss: 0.0050 - Val Loss: 0.0049
# No improvement for 20 epoch(s).
# Early stopping triggered after 132 epochs. Best val loss: 0.0035

# %%
# -----------------------------
# Load the Best Model
# -----------------------------
def load_model(checkpoint_path, device='cpu'):
    # Initialize the model
    model = Net(input_dim=NUM_INPUTS, output_dim=NUM_OUTPUTS)
    model.load_state_dict(torch.load(checkpoint_path, map_location=device))
    model.to(device)  # Ensure model is on the right device (CPU or GPU)
    model.eval()  # Set model to evaluation mode
    return model

# -----------------------------
# Make Predictions
# -----------------------------
def make_predictions(model, X_input, device='cpu'):
    # Convert the input to a tensor and move to the correct device
    X_input_tensor = torch.tensor(X_input, dtype=torch.float32).to(device)
    
    # Make the prediction (no gradients needed for inference)
    with torch.no_grad():
        predictions = model(X_input_tensor)

    return predictions.cpu().numpy()  # Convert back to NumPy array

# -----------------------------
# Usage
# -----------------------------
# Example path to checkpoint
checkpoint_path = "test.pth"

# Load model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = load_model(checkpoint_path, device=device)

# Example input (new data to predict on)
# Make sure this input has the same shape as the training data
X_input = np.array([25.0, 1e-14, 1e6, 129])  # Replace with actual data

# Log-transform the input if necessary (since you applied log10 during training)
X_input = np.log10(X_input)

# Make prediction
predictions = make_predictions(model, X_input, device=device)
print("Predictions: ", predictions)
# Out:
# Predictions:  [-2.0972050e+01  9.4067365e-01  3.5403688e-03 -8.1906468e-03]
